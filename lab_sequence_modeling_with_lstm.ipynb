# %% [markdown]
# # Lab | Sequence Modeling with LSTM

# %%
import json
import tensorflow as tf
import csv
import random
import numpy as np

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers


embedding_dim = 100
max_length = 16
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size=  160000 #Your dataset size here. Experiment using smaller values (i.e. 16000), but don't forget to train on at least 160000 to see the best effects
test_portion=.1

corpus = []

# %%
#!wget --no-check-certificate \
    #https://storage.googleapis.com/laurencemoroney-blog.appspot.com/training_cleaned.csv \
    #-O /tmp/training_cleaned.csv

num_sentences = 0

with open("/content/training.1600000.processed.noemoticon.csv", encoding='latin1') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
      # Your Code here. Create list items where the first item is the text, found in row[5], and the second is the label. Note that the label is a '0' or a '4' in the text. When it's the former, make
      # your label to be 0, otherwise 1. Keep a count of the number of sentences in num_sentences
        # YOUR CODE HERE
        text = row [5]
        if row[0] == '0':
          label = 0
        else:
          label = 1
        list_item = [text, label]
        num_sentences += 1
        corpus.append(list_item)

# %%
print(num_sentences)
print(len(corpus))
print(corpus[1])

# Expected Output:
# 1600000
# 1600000
# ["is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!", 0]
# Out:
# 1600000
# 1600000
# ["is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!", 0]

# %%
sentences=[]
labels=[]
random.shuffle(corpus)
for x in range(training_size):
    sentences.append(corpus[x][0])
    labels.append(corpus[x][1])


tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)

word_index = tokenizer.word_index
vocab_size=len(word_index)

sequences = tokenizer.texts_to_sequences(sentences)
padded = pad_sequences(sequences, maxlen=max_length, padding='post')

split = int(test_portion * training_size)

test_sequences = padded[:split]
training_sequences = padded[:split]
test_labels = labels[:split]
training_labels = labels[:split]

# %%
print(vocab_size)
print(word_index['i'])
# Expected Output
# 138858
# 1
# Out:
# 138944
# 1

# %%
# Note this is the 100 dimension version of GloVe from Stanford
# I unzipped and hosted it on my site to make this notebook easier
#!wget --no-check-certificate \
    #https://storage.googleapis.com/laurencemoroney-blog.appspot.com/glove.6B.100d.txt \
    #-O /tmp/glove.6B.100d.txt
embeddings_index = {};
with open('/content/glove.6B.100d.txt') as f:
    for line in f:
        values = line.split();
        word = values[0];
        coefs = np.asarray(values[1:], dtype='float32');
        embeddings_index[word] = coefs;

embeddings_matrix = np.zeros((vocab_size+1, embedding_dim));
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word);
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector;

# %%
print(len(embeddings_matrix))
# Expected Output
# 138859
# Out:
# 138945

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size+1, embedding_dim, input_length=max_length, weights=[embeddings_matrix], trainable=False),
    # YOUR CODE HERE - experiment with combining different types, such as convolutions and LSTMs
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.LSTM(128),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

num_epochs = 50
history = model.fit(np.array(training_sequences), np.array(training_labels), epochs=num_epochs, validation_data=(np.array(test_sequences), np.array(test_labels)), verbose=2)

print("Training Complete")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 16, 100)           13894500
#
#  conv1d_3 (Conv1D)           (None, 12, 128)           64128
#
#  max_pooling1d_3 (MaxPoolin  (None, 6, 128)            0
#  g1D)
#
#  lstm_6 (LSTM)               (None, 6, 128)            131584
#
#  lstm_7 (LSTM)               (None, 128)               131584
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dense_7 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 14238437 (54.32 MB)
# Trainable params: 343937 (1.31 MB)
# Non-trainable params: 13894500 (53.00 MB)
# _________________________________________________________________
# Epoch 1/50
# 500/500 - 12s - loss: 0.6165 - accuracy: 0.6568 - val_loss: 0.5472 - val_accuracy: 0.7224 - 12s/epoch - 23ms/step
# Epoch 2/50
# 500/500 - 4s - loss: 0.5427 - accuracy: 0.7230 - val_loss: 0.4887 - val_accuracy: 0.7638 - 4s/epoch - 7ms/step
# Epoch 3/50
# 500/500 - 5s - loss: 0.4889 - accuracy: 0.7638 - val_loss: 0.4166 - val_accuracy: 0.8229 - 5s/epoch - 10ms/step
# Epoch 4/50
# 500/500 - 4s - loss: 0.4165 - accuracy: 0.8083 - val_loss: 0.3125 - val_accuracy: 0.8764 - 4s/epoch - 8ms/step
# Epoch 5/50
# 500/500 - 4s - loss: 0.3462 - accuracy: 0.8456 - val_loss: 0.2540 - val_accuracy: 0.9054 - 4s/epoch - 7ms/step
# Epoch 6/50
# 500/500 - 4s - loss: 0.2712 - accuracy: 0.8848 - val_loss: 0.1948 - val_accuracy: 0.9225 - 4s/epoch - 7ms/step
# Epoch 7/50
# 500/500 - 6s - loss: 0.2087 - accuracy: 0.9146 - val_loss: 0.1280 - val_accuracy: 0.9609 - 6s/epoch - 11ms/step
# Epoch 8/50
# 500/500 - 4s - loss: 0.1655 - accuracy: 0.9347 - val_loss: 0.1453 - val_accuracy: 0.9377 - 4s/epoch - 9ms/step
# Epoch 9/50
# 500/500 - 4s - loss: 0.1262 - accuracy: 0.9506 - val_loss: 0.0807 - val_accuracy: 0.9727 - 4s/epoch - 7ms/step
# Epoch 10/50
# 500/500 - 4s - loss: 0.1001 - accuracy: 0.9621 - val_loss: 0.0645 - val_accuracy: 0.9773 - 4s/epoch - 7ms/step
# Epoch 11/50
# 500/500 - 6s - loss: 0.0882 - accuracy: 0.9663 - val_loss: 0.0479 - val_accuracy: 0.9819 - 6s/epoch - 12ms/step
# Epoch 12/50
# 500/500 - 6s - loss: 0.0751 - accuracy: 0.9710 - val_loss: 0.0426 - val_accuracy: 0.9844 - 6s/epoch - 12ms/step
# Epoch 13/50
# 500/500 - 4s - loss: 0.0726 - accuracy: 0.9714 - val_loss: 0.0385 - val_accuracy: 0.9866 - 4s/epoch - 7ms/step
# Epoch 14/50
# 500/500 - 5s - loss: 0.0640 - accuracy: 0.9749 - val_loss: 0.0382 - val_accuracy: 0.9848 - 5s/epoch - 9ms/step
# Epoch 15/50
# 500/500 - 6s - loss: 0.0517 - accuracy: 0.9799 - val_loss: 0.0443 - val_accuracy: 0.9841 - 6s/epoch - 11ms/step
# Epoch 16/50
# 500/500 - 5s - loss: 0.0506 - accuracy: 0.9798 - val_loss: 0.0318 - val_accuracy: 0.9878 - 5s/epoch - 9ms/step
# Epoch 17/50
# 500/500 - 4s - loss: 0.0514 - accuracy: 0.9801 - val_loss: 0.0565 - val_accuracy: 0.9756 - 4s/epoch - 7ms/step
# Epoch 18/50
# 500/500 - 5s - loss: 0.0461 - accuracy: 0.9819 - val_loss: 0.0241 - val_accuracy: 0.9918 - 5s/epoch - 9ms/step
# Epoch 19/50
# 500/500 - 4s - loss: 0.0402 - accuracy: 0.9846 - val_loss: 0.0225 - val_accuracy: 0.9911 - 4s/epoch - 9ms/step
# Epoch 20/50
# 500/500 - 4s - loss: 0.0373 - accuracy: 0.9864 - val_loss: 0.0272 - val_accuracy: 0.9888 - 4s/epoch - 7ms/step
# Epoch 21/50
# 500/500 - 4s - loss: 0.0453 - accuracy: 0.9827 - val_loss: 0.0392 - val_accuracy: 0.9861 - 4s/epoch - 7ms/step
# Epoch 22/50
# 500/500 - 6s - loss: 0.0402 - accuracy: 0.9841 - val_loss: 0.0237 - val_accuracy: 0.9909 - 6s/epoch - 11ms/step
# Epoch 23/50
# 500/500 - 4s - loss: 0.0349 - accuracy: 0.9862 - val_loss: 0.0250 - val_accuracy: 0.9901 - 4s/epoch - 8ms/step
# Epoch 24/50
# 500/500 - 4s - loss: 0.0389 - accuracy: 0.9858 - val_loss: 0.0174 - val_accuracy: 0.9930 - 4s/epoch - 7ms/step
# Epoch 25/50
# 500/500 - 4s - loss: 0.0377 - accuracy: 0.9858 - val_loss: 0.0333 - val_accuracy: 0.9869 - 4s/epoch - 7ms/step
# Epoch 26/50
# 500/500 - 5s - loss: 0.0292 - accuracy: 0.9884 - val_loss: 0.0193 - val_accuracy: 0.9921 - 5s/epoch - 10ms/step
# Epoch 27/50
# 500/500 - 4s - loss: 0.0348 - accuracy: 0.9872 - val_loss: 0.0351 - val_accuracy: 0.9868 - 4s/epoch - 8ms/step
# Epoch 28/50
# 500/500 - 4s - loss: 0.0318 - accuracy: 0.9885 - val_loss: 0.0284 - val_accuracy: 0.9896 - 4s/epoch - 7ms/step
# Epoch 29/50
# 500/500 - 4s - loss: 0.0304 - accuracy: 0.9884 - val_loss: 0.0380 - val_accuracy: 0.9850 - 4s/epoch - 7ms/step
# Epoch 30/50
# 500/500 - 6s - loss: 0.0281 - accuracy: 0.9893 - val_loss: 0.0557 - val_accuracy: 0.9803 - 6s/epoch - 12ms/step
# Epoch 31/50
# 500/500 - 4s - loss: 0.0279 - accuracy: 0.9892 - val_loss: 0.0156 - val_accuracy: 0.9937 - 4s/epoch - 8ms/step
# Epoch 32/50
# 500/500 - 4s - loss: 0.0344 - accuracy: 0.9874 - val_loss: 0.0238 - val_accuracy: 0.9908 - 4s/epoch - 8ms/step
# Epoch 33/50
# 500/500 - 4s - loss: 0.0266 - accuracy: 0.9895 - val_loss: 0.0162 - val_accuracy: 0.9946 - 4s/epoch - 8ms/step
# Epoch 34/50
# 500/500 - 6s - loss: 0.0246 - accuracy: 0.9900 - val_loss: 0.0211 - val_accuracy: 0.9917 - 6s/epoch - 12ms/step
# Epoch 35/50
# 500/500 - 4s - loss: 0.0316 - accuracy: 0.9874 - val_loss: 0.0187 - val_accuracy: 0.9934 - 4s/epoch - 7ms/step
# Epoch 36/50
# 500/500 - 4s - loss: 0.0289 - accuracy: 0.9891 - val_loss: 0.0415 - val_accuracy: 0.9851 - 4s/epoch - 7ms/step
# Epoch 37/50
# 500/500 - 4s - loss: 0.0247 - accuracy: 0.9899 - val_loss: 0.0167 - val_accuracy: 0.9944 - 4s/epoch - 8ms/step
# Epoch 38/50
# 500/500 - 5s - loss: 0.0230 - accuracy: 0.9908 - val_loss: 0.0262 - val_accuracy: 0.9898 - 5s/epoch - 10ms/step
# Epoch 39/50
# 500/500 - 4s - loss: 0.0291 - accuracy: 0.9881 - val_loss: 0.0226 - val_accuracy: 0.9916 - 4s/epoch - 7ms/step
# Epoch 40/50
# 500/500 - 4s - loss: 0.0179 - accuracy: 0.9924 - val_loss: 0.0175 - val_accuracy: 0.9937 - 4s/epoch - 7ms/step
# Epoch 41/50
# 500/500 - 4s - loss: 0.0280 - accuracy: 0.9899 - val_loss: 0.0209 - val_accuracy: 0.9939 - 4s/epoch - 8ms/step
# Epoch 42/50
# 500/500 - 5s - loss: 0.0147 - accuracy: 0.9948 - val_loss: 0.0207 - val_accuracy: 0.9912 - 5s/epoch - 10ms/step
# Epoch 43/50
# 500/500 - 4s - loss: 0.0248 - accuracy: 0.9905 - val_loss: 0.0125 - val_accuracy: 0.9946 - 4s/epoch - 7ms/step
# Epoch 44/50
# 500/500 - 4s - loss: 0.0251 - accuracy: 0.9907 - val_loss: 0.0176 - val_accuracy: 0.9933 - 4s/epoch - 7ms/step
# Epoch 45/50
# 500/500 - 5s - loss: 0.0238 - accuracy: 0.9908 - val_loss: 0.0145 - val_accuracy: 0.9942 - 5s/epoch - 10ms/step
# Epoch 46/50
# 500/500 - 5s - loss: 0.0231 - accuracy: 0.9909 - val_loss: 0.0119 - val_accuracy: 0.9954 - 5s/epoch - 9ms/step
# Epoch 47/50
# 500/500 - 4s - loss: 0.0221 - accuracy: 0.9916 - val_loss: 0.0125 - val_accuracy: 0.9942 - 4s/epoch - 7ms/step
# Epoch 48/50
# 500/500 - 4s - loss: 0.0203 - accuracy: 0.9914 - val_loss: 0.0155 - val_accuracy: 0.9945 - 4s/epoch - 7ms/step
# Epoch 49/50
# 500/500 - 4s - loss: 0.0241 - accuracy: 0.9906 - val_loss: 0.0164 - val_accuracy: 0.9939 - 4s/epoch - 9ms/step
# Epoch 50/50
# 500/500 - 5s - loss: 0.0211 - accuracy: 0.9914 - val_loss: 0.0188 - val_accuracy: 0.9921 - 5s/epoch - 9ms/step
# Training Complete

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Accuracy", "Validation Accuracy"])

plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Validation Loss"])

plt.figure()


# Expected Output
# A chart where the validation loss does not increase sharply!
